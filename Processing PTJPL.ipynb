# %%
import pandas as pd
from PTJPL_sensitivity import generate_PTJPL_inputs, process_PTJPL_table

# %%
net_radiation_df = pd.read_csv("calval_final_50_verma_net_radiation_outputs.csv")
net_radiation_df
# Out:
#      Unnamed: 0.1   tower      lat      lon  orbit  scene   tile  \
# 0               0  US-Ha2  42.5393 -72.1779   9254      9  18TYN
# 1               1  US-Ha2  42.5393 -72.1779  10150      9  18TYN
# 2               2  US-Ha2  42.5393 -72.1779  10352      9  18TYN
# 3               3  US-Ha2  42.5393 -72.1779  10684      7  18TYN
# 4               4  US-Ha2  42.5393 -72.1779  11069      8  18TYN
# ..            ...     ...      ...      ...    ...    ...    ...
# 247           247  US-xUK  39.0404 -95.1921  11909      6  15SUD
# 248           248  US-xUK  39.0404 -95.1921  16668      8  15SUD
# 249           249  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 250           250  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 251           251  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC  doy  ...         UV         VIS  \
# 0    2020-02-22 00:00:00  2020-02-22   53  ...   0.000000    0.000000
# 1    2020-04-20 00:00:00  2020-04-20  111  ...   0.000000    0.000000
# 2    2020-05-03 00:00:00  2020-05-03  124  ...   0.000000    0.000000
# 3    2020-05-24 00:00:00  2020-05-24  145  ...   0.592462    3.964455
# 4    2020-06-18 00:00:00  2020-06-18  170  ...   1.386834    9.353725
# ..                   ...         ...  ...  ...        ...         ...
# 247  2020-08-11 00:00:00  2020-08-11  224  ...   2.746542   17.376796
# 248  2021-06-14 00:00:00  2021-06-14  165  ...  13.811569  125.868830
# 249  2021-06-23 00:00:00  2021-06-23  174  ...  14.346120  119.526664
# 250  2021-06-23 00:00:00  2021-06-23  174  ...  14.346120  119.526664
# 251  2020-09-04 00:00:00  2020-09-04  248  ...   0.594074    3.113654
#
#             NIR    VISdiff    NIRdiff     VISdir      NIRdir      SWout  \
# 0      0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 1      0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 2      0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# 3      3.539386   3.627162   3.519072   0.337294    0.020315   0.662989
# 4      8.820494   7.418505   8.696527   1.935220    0.123967   2.254700
# ..          ...        ...        ...        ...         ...        ...
# 247   12.682295  14.372975  12.682295   3.003822    0.000000   5.351180
# 248  142.625977  32.456092  15.308895  93.412739  127.317082  27.991697
# 249  125.834733  38.645010  27.577193  80.881654   98.257540  28.021802
# 250  125.834733  38.645010  27.577193  80.881654   98.257540  28.021802
# 251    2.262866   2.846623   2.261136   0.267030    0.001731   0.797800
#
#            LWin       LWout
# 0    223.482510  310.837408
# 1    249.470817  483.042043
# 2    293.358154  368.124775
# 3           NaN  385.565499
# 4    380.029433  454.438012
# ..          ...         ...
# 247  414.848071  439.377199
# 248         NaN  405.251251
# 249         NaN  388.004691
# 250  400.532814  463.095778
# 251         NaN  339.018157
#
# [252 rows x 77 columns]

# %%
inputs_df = generate_PTJPL_inputs(net_radiation_df)
inputs_df.to_csv("calval_final_50_PTJPL_inputs.csv", index=False)
inputs_df
# Out:
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.5545
# Topt: 0.0
# fAPARmax: 0.44620000000000004
# Topt: 0.0
# fAPARmax: 0.44620000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.47390000000000004
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.4958
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.49510000000000004
# Topt: 0.0
# fAPARmax: 0.4913
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 0.0
# fAPARmax: 0.4989
# Topt: 6.69
# fAPARmax: 0.604
# Topt: 6.69
# fAPARmax: 0.604
# Topt: 6.69
# fAPARmax: 0.604
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 11.44
# fAPARmax: 0.47250000000000003
# Topt: 13.57
# fAPARmax: 0.4944
# Topt: 13.57
# fAPARmax: 0.4944
# Topt: 13.57
# fAPARmax: 0.4944
# Topt: 0.0
# fAPARmax: 0.3301
# Topt: 0.0
# fAPARmax: 0.3301
# Topt: 0.6900000000000001
# fAPARmax: 0.4423
# Topt: 0.6900000000000001
# fAPARmax: 0.4423
# Topt: 0.6900000000000001
# fAPARmax: 0.4423
# Topt: 0.6900000000000001
# fAPARmax: 0.4423
# Topt: 0.6900000000000001
# fAPARmax: 0.4423
# Topt: 0.6900000000000001
# fAPARmax: 0.4423
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 5.8
# fAPARmax: 0.46640000000000004
# Topt: 0.0
# fAPARmax: 0.4592
#      Unnamed: 0.1   tower      lat      lon  orbit  scene   tile  \
# 0               0  US-Ha2  42.5393 -72.1779   9254      9  18TYN
# 1               1  US-Ha2  42.5393 -72.1779  10150      9  18TYN
# 2               2  US-Ha2  42.5393 -72.1779  10352      9  18TYN
# 3               3  US-Ha2  42.5393 -72.1779  10684      7  18TYN
# 4               4  US-Ha2  42.5393 -72.1779  11069      8  18TYN
# ..            ...     ...      ...      ...    ...    ...    ...
# 247           247  US-xUK  39.0404 -95.1921  11909      6  15SUD
# 248           248  US-xUK  39.0404 -95.1921  16668      8  15SUD
# 249           249  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 250           250  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 251           251  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC  doy  ...    VISdiff    NIRdiff  \
# 0    2020-02-22 00:00:00  2020-02-22   53  ...   0.000000   0.000000
# 1    2020-04-20 00:00:00  2020-04-20  111  ...   0.000000   0.000000
# 2    2020-05-03 00:00:00  2020-05-03  124  ...   0.000000   0.000000
# 3    2020-05-24 00:00:00  2020-05-24  145  ...   3.627162   3.519072
# 4    2020-06-18 00:00:00  2020-06-18  170  ...   7.418505   8.696527
# ..                   ...         ...  ...  ...        ...        ...
# 247  2020-08-11 00:00:00  2020-08-11  224  ...  14.372975  12.682295
# 248  2021-06-14 00:00:00  2021-06-14  165  ...  32.456092  15.308895
# 249  2021-06-23 00:00:00  2021-06-23  174  ...  38.645010  27.577193
# 250  2021-06-23 00:00:00  2021-06-23  174  ...  38.645010  27.577193
# 251  2020-09-04 00:00:00  2020-09-04  248  ...   2.846623   2.261136
#
#         VISdir      NIRdir      SWout        LWin       LWout  hour_of_day  \
# 0     0.000000    0.000000   0.000000  223.482510  310.837408           19
# 1     0.000000    0.000000   0.000000  249.470817  483.042043           19
# 2     0.000000    0.000000   0.000000  293.358154  368.124775           19
# 3     0.337294    0.020315   0.662989         NaN  385.565499           19
# 4     1.935220    0.123967   2.254700  380.029433  454.438012           19
# ..         ...         ...        ...         ...         ...          ...
# 247   3.003822    0.000000   5.351180  414.848071  439.377199           17
# 248  93.412739  127.317082  27.991697         NaN  405.251251           17
# 249  80.881654   98.257540  28.021802         NaN  388.004691           17
# 250  80.881654   98.257540  28.021802  400.532814  463.095778           17
# 251   0.267030    0.001731   0.797800         NaN  339.018157           18
#
#      Topt  fAPARmax
# 0     0.0    0.5545
# 1     0.0    0.5545
# 2     0.0    0.5545
# 3     0.0    0.5545
# 4     0.0    0.5545
# ..    ...       ...
# 247   5.8    0.4664
# 248   5.8    0.4664
# 249   5.8    0.4664
# 250   5.8    0.4664
# 251   0.0    0.4592
#
# [252 rows x 80 columns]

# %%
inputs_df.ST_C
# Out:
# 0       0.89
# 1      35.39
# 2      13.17
# 3      15.61
# 4      28.03
#        ...
# 247    26.43
# 248    22.77
# 249    17.11
# 250    30.71
# 251     6.47
# Name: ST_C, Length: 252, dtype: float64

# %%
outputs_df = process_PTJPL_table(inputs_df)
outputs_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 outputs_df = process_PTJPL_table(inputs_df)
#       2 outputs_df
#
# File ~/Projects/ET-Sensitivity/PTJPL_sensitivity/PTJPL_sensitivity.py:131, in process_PTJPL_table(input_df)
#     128 else:
#     129     G = None
# --> 131 results = process_PTJPL(
#     132     # ST_C = ST_C,
#     133     # emissivity=emissivity,
#     134     NDVI=NDVI,
#     135     # albedo=albedo,
#     136     Ta_C=Ta_C,
#     137     RH=RH,
#     138     Rn=Rn,
#     139     Topt=Topt,
#     140     fAPARmax=fAPARmax,
#     141     G=G
#     142 )
#     144 output_df = input_df.copy()
#     146 for key, value in results.items():
#
# File ~/Projects/ET-Sensitivity/PTJPL/PTJPL.py:103, in process_PTJPL(Rn, G, NDVI, Ta_C, RH, Topt, fAPARmax, delta_Pa, gamma_Pa, epsilon, beta_Pa, PT_alpha)
#      98 results["Rn_soil"] = Rn_soil
#     100 # calculate soil evaporation (LEs) from relative surface wetness, soil moisture constraint,
#     101 # priestley taylor coefficient, epsilon = delta / (delta + gamma), net radiation of the soil,
#     102 # and soil heat flux
# --> 103 LE_soil = np.clip((fwet + fSM * (1 - fwet)) * PT_alpha * epsilon * (Rn_soil - G), 0, None)
#     104 results["LE_soil"] = LE_soil
#     106 # canopy transpiration
#     107
#     108 # calculate net radiation of the canopy from net radiation of the soil
#
# TypeError: unsupported operand type(s) for -: 'float' and 'NoneType'
